# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# for visualization
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
np.random.seed(42)
x0=np.random.normal(loc=[5,5], scale=[1,1],size=(50,2))
y0 = np.zeros(50)

# %%
# Logistic Regression
clf1 = LogisticRegression(
    random_state=1,
    solver='lbfgs'
)

# K-Nearest Neighbors
clf2 = KNeighborsClassifier(
    n_neighbors=5
)

# Decision Tree
clf3 = DecisionTreeClassifier(
    max_depth=3,
    random_state=1
)

print("Individual classifiers defined.")
# Out:
# Individual classifiers defined.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import VotingClassifier

# Load dataset
iris = load_iris()

X = iris.data
y = iris.target

# Split the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=1,
    stratify=y
)

# Scale the training and testing data
scaler = StandardScaler()

X_train_scaled_ensemble = scaler.fit_transform(X_train)
X_test_scaled_ensemble = scaler.transform(X_test)

# Create the Voting Classifier
voting_clf = VotingClassifier(
    estimators=[
        ('lr', clf1),
        ('knn', clf2),
        ('dt', clf3)
    ],
    voting='hard'
)

# Train the Voting Classifier
voting_clf.fit(
    X_train_scaled_ensemble,
    y_train
)

print("Voting Classifier (hard voting) trained successfully.")
# Out:
# Voting Classifier (hard voting) trained successfully.

# %%
from sklearn.metrics import accuracy_score, classification_report

# Make predictions
y_pred_ensemble = voting_clf.predict(
    X_test_scaled_ensemble
)

# Calculate accuracy
ensemble_accuracy = accuracy_score(
    y_test,
    y_pred_ensemble
)

# Generate classification report
ensemble_report = classification_report(
    y_test,
    y_pred_ensemble
)

print(f"Ensemble Model Accuracy: {ensemble_accuracy:.2f}")
print("Ensemble Model Classification Report:")
print(ensemble_report)
# Out:
# Ensemble Model Accuracy: 0.97
# Ensemble Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.91      1.00      0.95        10
#            2       1.00      0.90      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30
